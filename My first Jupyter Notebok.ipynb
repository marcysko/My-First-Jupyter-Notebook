# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# **Marcia Skousen**
#
# Data Analyst

# %% [markdown]
# *I am interested in Data Science because I have great attention to detail and I like investigating solutions. I want to combine my healthcare knowledge with the insights data science holds for the future of medicine.*

# %% [markdown]
# ### My code in cell 5 is supposed to add a sum of two numbers

# %%
num1 = 3
num2 = 8

sum = num1 + num2

print(sum)
# Out:
# 11

# %% [markdown]
# - Data Science is fun!
# - There are many open data science jobs
# - I don't have to be a coding expert to succeed
#
# >My favorite blockquote
#
# <ol>
#     <li>Cats</li>
#     <li>Dogs</li>
#     <li>kittens</li>
#     <li>puppies</li>
#     </ol>
